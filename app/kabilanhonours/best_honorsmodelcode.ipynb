# %%
from google.colab import drive
drive.mount('/content/drive')

KP_ROOT  ="/content/drive/MyDrive/109-keypoints-all-64"
JSON_DIR = f"{KP_ROOT}/Cutdown-json"

TRAIN_MAN = f"{JSON_DIR}/Train_150_kp.json"
VAL_MAN   = f"{JSON_DIR}/Valid_150_kp.json"
TEST_MANS = {
    "ITW": f"{JSON_DIR}/Test_ITW_150_kp.json",
    "STU": f"{JSON_DIR}/Test_STU_150_kp.json",
    "SYN": f"{JSON_DIR}/Test_SYN_150_kp.json",
    "TED": f"{JSON_DIR}/Test_TED_150_kp.json",
}

CALLBACK_DIR = f"{KP_ROOT}/model-callbacks-keras"
MODEL_PATH   = f"{CALLBACK_DIR}/bilstm_best.keras"

import os, json, numpy as np, tensorflow as tf
from pathlib import Path
os.makedirs(CALLBACK_DIR, exist_ok=True)

print("KP_ROOT:", KP_ROOT)
print("JSON_DIR:", JSON_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# KP_ROOT: /content/drive/MyDrive/109-keypoints-all-64
# JSON_DIR: /content/drive/MyDrive/109-keypoints-all-64/Cutdown-json

# %%
import json, numpy as np, os
from pathlib import Path

LABEL_MAP_JSON = f"{KP_ROOT}/label_map.json"
STATS_JSON     = f"{KP_ROOT}/stats.json"

def build_label_map(train_manifest, out_json):
    with open(train_manifest, "r", encoding="utf-8") as f:
        d = json.load(f)
    glosses = sorted({v["gloss"] for _, v in d.items()})
    lm = {g:i for i,g in enumerate(glosses)}
    with open(out_json, "w", encoding="utf-8") as f:
        json.dump(lm, f, indent=2, ensure_ascii=False)
    print(f"Saved label_map to {out_json} with {len(lm)} classes.")
    return out_json

def compute_stats(train_manifest, kp_root, out_json, max_items=None):
    with open(train_manifest, "r", encoding="utf-8") as f:
        items = list(json.load(f).items())

    feats = []
    take = items if max_items is None else items[:max_items]
    for _, meta in take:
        p = Path(kp_root) / meta["npz"]
        d = np.load(p)
        x = d["x"].astype(np.float32).reshape(d["x"].shape[0], -1) 
        m = d["m"].astype(np.float32)                             
        m_feat = np.repeat(m, 2, axis=1)                            
        x = x * m_feat
        feats.append(x)

    X = np.concatenate(feats, axis=0)  
    mu = X.mean(axis=0).tolist()
    sd = X.std(axis=0).tolist()
    with open(out_json, "w") as f:
        json.dump({"mean": mu, "std": sd}, f)
    print(f"Saved stats to {out_json}")
    return out_json

if not os.path.exists(LABEL_MAP_JSON):
    build_label_map(TRAIN_MAN, LABEL_MAP_JSON)
else:
    print("label_map.json already exists")

if not os.path.exists(STATS_JSON):
    compute_stats(TRAIN_MAN, KP_ROOT, STATS_JSON)   
else:
    print("stats.json already exists")

with open(LABEL_MAP_JSON, "r") as f:
    lm = json.load(f)
print("Classes:", len(lm))
# Out:
# label_map.json already exists
# stats.json already exists
# Classes: 109

# %%
import tensorflow as tf
import numpy as np
import json, os
from pathlib import Path, PureWindowsPath


with open(LABEL_MAP_JSON, "r", encoding="utf-8") as f:
    label_map = json.load(f)
inv_label = {v:k for k,v in label_map.items()}

with open(STATS_JSON, "r") as f:
    stats = json.load(f)
mu = np.array(stats["mean"], dtype=np.float32)
sd = np.array(stats["std"],  dtype=np.float32)
sd[sd < 1e-6] = 1.0

T = 64
F = 84

def resolve_npz(npz_rel):
   
    rel = Path(PureWindowsPath(npz_rel))
    return str(Path(KP_ROOT) / rel)

def load_index(man_path):
    with open(man_path, "r", encoding="utf-8") as f:
        d = json.load(f)
    items = []
    for _, meta in d.items():
        items.append((meta["npz"], label_map[str(meta["gloss"])]))
    return items

def _decode_tf_string(s):
    if hasattr(s, "numpy"):
        return s.numpy().decode("utf-8")
    if isinstance(s, (bytes, bytearray, np.bytes_)):
        return bytes(s).decode("utf-8")
    if isinstance(s, str):
        return s
    return str(s)

def npz_to_example(npz_rel, y):
    p = resolve_npz(_decode_tf_string(npz_rel))
    d = np.load(p)
    x = d["x"].astype(np.float32)       # [T,42,2]
    m = d["m"].astype(np.float32)       # [T,42]
    x = x.reshape(x.shape[0], -1)       # [T,84]
    m_feat = np.repeat(m, 2, axis=1)    # [T,84]
    x = x * m_feat                      # zero missing
    x = (x - mu) / sd                   # z-score
    return x, np.int32(y)

def tf_load(npz_rel, y):
    x, y = tf.py_function(
        func=npz_to_example,
        inp=[npz_rel, y],
        Tout=[tf.float32, tf.int32]
    )
    x.set_shape([T, F])
    y.set_shape([])
    return x, y

def make_dataset(man_path, bsz=128, shuffle=True):
    items = load_index(man_path)
    paths = tf.constant([p for p,_ in items], dtype=tf.string)
    ys    = tf.constant([y for _,y in items], dtype=tf.int32)
    ds = tf.data.Dataset.from_tensor_slices((paths, ys))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(items), reshuffle_each_iteration=True)
    ds = ds.map(tf_load, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(bsz).prefetch(tf.data.AUTOTUNE)
    return ds, len(items)

BATCH = 128
train_ds, Ntrain = make_dataset(TRAIN_MAN, bsz=BATCH, shuffle=True)
val_ds,   Nval   = make_dataset(VAL_MAN,   bsz=BATCH, shuffle=False)
print("Ntrain:", Ntrain, "Nval:", Nval, "| Classes:", len(label_map))
# Out:
# Ntrain: 1308 Nval: 218 | Classes: 109

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

NUM_CLASSES = len(label_map)

def build_model(T=64, F=84, C=NUM_CLASSES):
    inp = keras.Input(shape=(T, F), name="seq")
    x = layers.Masking(mask_value=0.0)(inp)

    x = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Bidirectional(layers.LSTM(256, return_sequences=False))(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    out = layers.Dense(C, activation="softmax")(x)

    model = keras.Model(inp, out, name="bilstm_kp")
    return model

model = build_model(T, F, NUM_CLASSES)
model.summary()

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# Model: "bilstm_kp"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ seq (InputLayer)    │ (None, 64, 84)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_20        │ (None, 64, 84)    │          0 │ seq[0][0]         │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking_10          │ (None, 64, 84)    │          0 │ seq[0][0]         │
# │ (Masking)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any_30 (Any)        │ (None, 64)        │          0 │ not_equal_20[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_20    │ (None, 64, 512)   │    698,368 │ masking_10[0][0], │
# │ (Bidirectional)     │                   │            │ any_30[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 64, 512)   │          0 │ bidirectional_20… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_21    │ (None, 512)       │  1,574,912 │ dropout_30[0][0], │
# │ (Bidirectional)     │                   │            │ any_30[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 512)       │          0 │ bidirectional_21… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 256)       │    131,328 │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 256)       │          0 │ dense_20[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 109)       │     28,013 │ dropout_32[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,432,621 (9.28 MB)
#  Trainable params: 2,432,621 (9.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger

ckpt = ModelCheckpoint(
    MODEL_PATH,
    monitor="val_accuracy",
    mode="max",
    save_best_only=True,
    save_weights_only=False,   
    verbose=1
)
lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, verbose=1)
es = EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True, verbose=1)
log = CSVLogger(f"{CALLBACK_DIR}/train_log.csv")

callbacks = [ckpt, lr, es, log]
print("Callbacks will save to:", CALLBACK_DIR)
# Out:
# Callbacks will save to: /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras

# %%
EPOCHS = 60
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
print("Best model saved at:", MODEL_PATH)
# Out:
# Epoch 1/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.0058 - loss: 4.7128
# Epoch 1: val_accuracy improved from -inf to 0.01835, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 354ms/step - accuracy: 0.0066 - loss: 4.7106 - val_accuracy: 0.0183 - val_loss: 4.6121 - learning_rate: 0.0010
# Epoch 2/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.0355 - loss: 4.5176
# Epoch 2: val_accuracy improved from 0.01835 to 0.05963, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - accuracy: 0.0362 - loss: 4.5118 - val_accuracy: 0.0596 - val_loss: 4.2871 - learning_rate: 0.0010
# Epoch 3/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.0725 - loss: 4.1589
# Epoch 3: val_accuracy improved from 0.05963 to 0.10092, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 296ms/step - accuracy: 0.0744 - loss: 4.1488 - val_accuracy: 0.1009 - val_loss: 3.8433 - learning_rate: 0.0010
# Epoch 4/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.1422 - loss: 3.6832
# Epoch 4: val_accuracy improved from 0.10092 to 0.16972, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 303ms/step - accuracy: 0.1423 - loss: 3.6691 - val_accuracy: 0.1697 - val_loss: 3.3597 - learning_rate: 0.0010
# Epoch 5/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.1865 - loss: 3.1531
# Epoch 5: val_accuracy improved from 0.16972 to 0.24312, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - accuracy: 0.1876 - loss: 3.1462 - val_accuracy: 0.2431 - val_loss: 2.9514 - learning_rate: 0.0010
# Epoch 6/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.2672 - loss: 2.7553
# Epoch 6: val_accuracy improved from 0.24312 to 0.28440, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - accuracy: 0.2665 - loss: 2.7582 - val_accuracy: 0.2844 - val_loss: 2.7805 - learning_rate: 0.0010
# Epoch 7/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.2894 - loss: 2.5676
# Epoch 7: val_accuracy improved from 0.28440 to 0.32110, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 300ms/step - accuracy: 0.2930 - loss: 2.5584 - val_accuracy: 0.3211 - val_loss: 2.5471 - learning_rate: 0.0010
# Epoch 8/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.3893 - loss: 2.1845
# Epoch 8: val_accuracy improved from 0.32110 to 0.39450, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 302ms/step - accuracy: 0.3864 - loss: 2.1878 - val_accuracy: 0.3945 - val_loss: 2.3197 - learning_rate: 0.0010
# Epoch 9/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.4424 - loss: 1.9759
# Epoch 9: val_accuracy improved from 0.39450 to 0.42202, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - accuracy: 0.4409 - loss: 1.9821 - val_accuracy: 0.4220 - val_loss: 2.1198 - learning_rate: 0.0010
# Epoch 10/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.4424 - loss: 1.8055
# Epoch 10: val_accuracy did not improve from 0.42202
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - accuracy: 0.4413 - loss: 1.8154 - val_accuracy: 0.4174 - val_loss: 2.2316 - learning_rate: 0.0010
# Epoch 11/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.5128 - loss: 1.6965
# Epoch 11: val_accuracy improved from 0.42202 to 0.45872, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 302ms/step - accuracy: 0.5126 - loss: 1.6922 - val_accuracy: 0.4587 - val_loss: 2.0719 - learning_rate: 0.0010
# Epoch 12/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.5637 - loss: 1.4727
# Epoch 12: val_accuracy improved from 0.45872 to 0.49541, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 300ms/step - accuracy: 0.5617 - loss: 1.4787 - val_accuracy: 0.4954 - val_loss: 1.9109 - learning_rate: 0.0010
# Epoch 13/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6236 - loss: 1.3025
# Epoch 13: val_accuracy did not improve from 0.49541
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - accuracy: 0.6207 - loss: 1.3059 - val_accuracy: 0.4954 - val_loss: 1.8861 - learning_rate: 0.0010
# Epoch 14/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.6209 - loss: 1.2800
# Epoch 14: val_accuracy did not improve from 0.49541
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - accuracy: 0.6229 - loss: 1.2701 - val_accuracy: 0.4862 - val_loss: 1.8371 - learning_rate: 0.0010
# Epoch 15/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.6589 - loss: 1.1076
# Epoch 15: val_accuracy improved from 0.49541 to 0.50000, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - accuracy: 0.6560 - loss: 1.1116 - val_accuracy: 0.5000 - val_loss: 1.7689 - learning_rate: 0.0010
# Epoch 16/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.6868 - loss: 1.0220
# Epoch 16: val_accuracy improved from 0.50000 to 0.50459, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 301ms/step - accuracy: 0.6865 - loss: 1.0208 - val_accuracy: 0.5046 - val_loss: 1.7643 - learning_rate: 0.0010
# Epoch 17/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.7118 - loss: 0.8921
# Epoch 17: val_accuracy improved from 0.50459 to 0.51835, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - accuracy: 0.7137 - loss: 0.8917 - val_accuracy: 0.5183 - val_loss: 1.7103 - learning_rate: 0.0010
# Epoch 18/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.7383 - loss: 0.8148
# Epoch 18: val_accuracy improved from 0.51835 to 0.52294, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 295ms/step - accuracy: 0.7351 - loss: 0.8238 - val_accuracy: 0.5229 - val_loss: 1.7977 - learning_rate: 0.0010
# Epoch 19/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.7214 - loss: 0.8569
# Epoch 19: val_accuracy improved from 0.52294 to 0.53211, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 302ms/step - accuracy: 0.7210 - loss: 0.8560 - val_accuracy: 0.5321 - val_loss: 1.7144 - learning_rate: 0.0010
# Epoch 20/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.7827 - loss: 0.7231
# Epoch 20: val_accuracy improved from 0.53211 to 0.56422, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 303ms/step - accuracy: 0.7791 - loss: 0.7320 - val_accuracy: 0.5642 - val_loss: 1.6758 - learning_rate: 0.0010
# Epoch 21/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.7901 - loss: 0.7100
# Epoch 21: val_accuracy improved from 0.56422 to 0.56881, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 306ms/step - accuracy: 0.7898 - loss: 0.7089 - val_accuracy: 0.5688 - val_loss: 1.6859 - learning_rate: 0.0010
# Epoch 22/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.8256 - loss: 0.5587
# Epoch 22: val_accuracy did not improve from 0.56881
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 288ms/step - accuracy: 0.8218 - loss: 0.5687 - val_accuracy: 0.5505 - val_loss: 1.6296 - learning_rate: 0.0010
# Epoch 23/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.8426 - loss: 0.5388
# Epoch 23: val_accuracy did not improve from 0.56881
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 292ms/step - accuracy: 0.8391 - loss: 0.5444 - val_accuracy: 0.5505 - val_loss: 1.8009 - learning_rate: 0.0010
# Epoch 24/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.8455 - loss: 0.5193
# Epoch 24: val_accuracy improved from 0.56881 to 0.58716, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 302ms/step - accuracy: 0.8432 - loss: 0.5211 - val_accuracy: 0.5872 - val_loss: 1.6703 - learning_rate: 0.0010
# Epoch 25/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8557 - loss: 0.4649
# Epoch 25: val_accuracy did not improve from 0.58716
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - accuracy: 0.8543 - loss: 0.4651 - val_accuracy: 0.5688 - val_loss: 1.8134 - learning_rate: 0.0010
# Epoch 26/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8718 - loss: 0.4062
# Epoch 26: val_accuracy did not improve from 0.58716
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - accuracy: 0.8724 - loss: 0.4059 - val_accuracy: 0.5872 - val_loss: 1.7463 - learning_rate: 5.0000e-04
# Epoch 27/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.8864 - loss: 0.3592
# Epoch 27: val_accuracy did not improve from 0.58716
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - accuracy: 0.8878 - loss: 0.3606 - val_accuracy: 0.5642 - val_loss: 1.7564 - learning_rate: 5.0000e-04
# Epoch 28/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.8993 - loss: 0.3315
# Epoch 28: val_accuracy improved from 0.58716 to 0.59633, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 315ms/step - accuracy: 0.9003 - loss: 0.3303 - val_accuracy: 0.5963 - val_loss: 1.8000 - learning_rate: 5.0000e-04
# Epoch 29/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9333 - loss: 0.2665
# Epoch 29: val_accuracy improved from 0.59633 to 0.60092, saving model to /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - accuracy: 0.9315 - loss: 0.2694 - val_accuracy: 0.6009 - val_loss: 1.7905 - learning_rate: 2.5000e-04
# Epoch 30/60
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9440 - loss: 0.2143
# Epoch 30: val_accuracy did not improve from 0.60092
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - accuracy: 0.9431 - loss: 0.2170 - val_accuracy: 0.5963 - val_loss: 1.7243 - learning_rate: 2.5000e-04
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Best model saved at: /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/bilstm_best.keras

# %%
import numpy as np
from collections import defaultdict

# reload best
best_model = tf.keras.models.load_model(MODEL_PATH)

def topk_acc(y_true, y_prob, k=5):
    topk = np.argpartition(-y_prob, kth=range(k), axis=1)[:, :k]
    return (topk == y_true[:, None]).any(axis=1).mean()

def evaluate_manifest(name, man_path, batch=256):
    ds, N = make_dataset(man_path, bsz=batch, shuffle=False)
    y_true = []
    y_prob = []
    for xb, yb in ds:
        pb = best_model(xb, training=False).numpy()
        y_prob.append(pb)
        y_true.append(yb.numpy())
    y_true = np.concatenate(y_true)
    y_prob = np.concatenate(y_prob)
    y_pred = y_prob.argmax(1)
    acc1 = (y_pred == y_true).mean()
    acc5 = topk_acc(y_true, y_prob, k=5)
    print(f"{name:>4} | top-1 {acc1:.3f} | top-5 {acc5:.3f} | N={len(y_true)}")
    return y_true, y_prob

print("=== Test splits ===")
test_results = {}
for k, p in TEST_MANS.items():
    y_true, y_prob = evaluate_manifest(k, p)
    test_results[k] = (y_true, y_prob)
# Out:
# === Test splits ===
#  ITW | top-1 0.596 | top-5 0.858 | N=218
#  STU | top-1 0.647 | top-5 0.940 | N=218
#  SYN | top-1 0.472 | top-5 0.743 | N=218
#  TED | top-1 0.537 | top-5 0.803 | N=218

# %%
import numpy as np

def inv(idx): return {v:k for k,v in label_map.items()}[idx]

def show_samples(man_path, n=10):
    ds, _ = make_dataset(man_path, bsz=1, shuffle=False)
    inv_map = {v:k for k,v in label_map.items()}
    shown = 0
    for xb, yb in ds:
        prob = best_model(xb, training=False).numpy()[0]
        top5 = prob.argsort()[-5:][::-1]
        true_idx = int(yb.numpy()[0])
        print(f"[{shown}] true: {inv_map[true_idx]:>12} | pred@5: {[inv_map[i] for i in top5]}")
        shown += 1
        if shown >= n: break

print("Sample predictions from ITW:")
show_samples(TEST_MANS["ITW"], n=10)
# Out:
# Sample predictions from ITW:
# [0] true:      BROTHER | pred@5: ['BROTHER', 'COLD', 'WRITE', 'CHAIR', 'BUT']
# [1] true:         LOVE | pred@5: ['LOVE', 'S', 'I', 'Y', 'NO']
# [2] true:         LOVE | pred@5: ['Y', 'I', 'LOVE', 'PERSON', 'NO']
# [3] true:        HELLO | pred@5: ['HELLO', 'B', 'STOP', 'LISTEN', 'E']
# [4] true:            Y | pred@5: ['SHOULD', 'IT', 'LEG', 'CHILD', 'TEACHER']
# [5] true:            H | pred@5: ['H', 'TIRED', 'MAN', 'TOMORROW', 'MUST']
# [6] true:         HAND | pred@5: ['HAND', 'STRONG', 'BOOK', 'NIGHT', 'HELP']
# [7] true:            N | pred@5: ['NO', 'N', 'YOU', 'LOVE', 'S']
# [8] true:      TEACHER | pred@5: ['X', 'SISTER', 'TEACHER', 'LOOK', 'T']
# [9] true:      HOLIDAY | pred@5: ['HOLIDAY', 'HOUSE', 'IF', 'WE', 'PLAY']

# %%
# !pip -q install scikit-learn
from sklearn.metrics import confusion_matrix
import numpy as np

def confusion_for_split(man_key):
    y_true, y_prob = test_results[man_key]
    y_pred = y_prob.argmax(1)
    cm = confusion_matrix(y_true, y_pred, labels=list(range(NUM_CLASSES)))
    print("Confusion matrix shape:", cm.shape)
    return cm

cm_itw = confusion_for_split("ITW")
# Out:
# Confusion matrix shape: (109, 109)

# %%
# --- Summarize test-set accuracies (top-1/top-5) and save as CSV ---
import numpy as np
import pandas as pd

def evaluate_to_dict(name, man_path):
    ds, _ = make_dataset(man_path, bsz=256, shuffle=False)
    y_true = []
    y_prob = []
    for xb, yb in ds:
        pb = best_model(xb, training=False).numpy()
        y_prob.append(pb)
        y_true.append(yb.numpy())
    y_true = np.concatenate(y_true)
    y_prob = np.concatenate(y_prob)
    y_pred = y_prob.argmax(1)
    top1 = (y_pred == y_true).mean()
    # top-5 this better work
    top5_hits = []
    top5_idx = np.argpartition(-y_prob, kth=range(5), axis=1)[:, :5]
    top5 = (top5_idx == y_true[:, None]).any(axis=1).mean()
    return {"split": name, "N": len(y_true), "top1": float(top1), "top5": float(top5)}

rows = []
for split_name, man_path in TEST_MANS.items():
    rows.append(evaluate_to_dict(split_name, man_path))

df = pd.DataFrame(rows).sort_values("split")
display(df.style.format({"top1": "{:.3f}", "top5": "{:.3f}"}))

csv_path = f"{CALLBACK_DIR}/test_summary.csv"
df.to_csv(csv_path, index=False)
print("Saved:", csv_path)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f74d2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f74d2_level0_col0" class="col_heading level0 col0" >split</th>
#       <th id="T_f74d2_level0_col1" class="col_heading level0 col1" >N</th>
#       <th id="T_f74d2_level0_col2" class="col_heading level0 col2" >top1</th>
#       <th id="T_f74d2_level0_col3" class="col_heading level0 col3" >top5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f74d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f74d2_row0_col0" class="data row0 col0" >ITW</td>
#       <td id="T_f74d2_row0_col1" class="data row0 col1" >218</td>
#       <td id="T_f74d2_row0_col2" class="data row0 col2" >0.596</td>
#       <td id="T_f74d2_row0_col3" class="data row0 col3" >0.858</td>
#     </tr>
#     <tr>
#       <th id="T_f74d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f74d2_row1_col0" class="data row1 col0" >STU</td>
#       <td id="T_f74d2_row1_col1" class="data row1 col1" >218</td>
#       <td id="T_f74d2_row1_col2" class="data row1 col2" >0.647</td>
#       <td id="T_f74d2_row1_col3" class="data row1 col3" >0.940</td>
#     </tr>
#     <tr>
#       <th id="T_f74d2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f74d2_row2_col0" class="data row2 col0" >SYN</td>
#       <td id="T_f74d2_row2_col1" class="data row2 col1" >218</td>
#       <td id="T_f74d2_row2_col2" class="data row2 col2" >0.472</td>
#       <td id="T_f74d2_row2_col3" class="data row2 col3" >0.743</td>
#     </tr>
#     <tr>
#       <th id="T_f74d2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f74d2_row3_col0" class="data row3 col0" >TED</td>
#       <td id="T_f74d2_row3_col1" class="data row3 col1" >218</td>
#       <td id="T_f74d2_row3_col2" class="data row3 col2" >0.537</td>
#       <td id="T_f74d2_row3_col3" class="data row3 col3" >0.803</td>
#     </tr>
#   </tbody>
# </table>
# Saved: /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/test_summary.csv

# %%
split_key = "ITW" 
ds, _ = make_dataset(TEST_MANS[split_key], bsz=256, shuffle=False)

all_true, all_pred = [], []
for xb, yb in ds:
    pb = best_model(xb, training=False).numpy()
    all_true.append(yb.numpy())
    all_pred.append(pb.argmax(1))

y_true = np.concatenate(all_true)
y_pred = np.concatenate(all_pred)

inv_map = {v:k for k,v in label_map.items()}
classes = sorted(label_map.values())
accs = []
for c in classes:
    mask = (y_true == c)
    if mask.sum() == 0:
        acc = np.nan
    else:
        acc = (y_pred[mask] == c).mean()
    accs.append({"gloss": inv_map[c], "acc": acc, "count": int(mask.sum())})

df_cls = pd.DataFrame(accs).sort_values(["count","acc"], ascending=[False,False])
display(df_cls.head(20).style.format({"acc": "{:.3f}"}))  # top 20 by support
# Out:
# <style type="text/css">
# </style>
# <table id="T_be69c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be69c_level0_col0" class="col_heading level0 col0" >gloss</th>
#       <th id="T_be69c_level0_col1" class="col_heading level0 col1" >acc</th>
#       <th id="T_be69c_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be69c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_be69c_row0_col0" class="data row0 col0" >ARM</td>
#       <td id="T_be69c_row0_col1" class="data row0 col1" >1.000</td>
#       <td id="T_be69c_row0_col2" class="data row0 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_be69c_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_be69c_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_be69c_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_be69c_row2_col0" class="data row2 col0" >BABY</td>
#       <td id="T_be69c_row2_col1" class="data row2 col1" >1.000</td>
#       <td id="T_be69c_row2_col2" class="data row2 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_be69c_row3_col0" class="data row3 col0" >BED</td>
#       <td id="T_be69c_row3_col1" class="data row3 col1" >1.000</td>
#       <td id="T_be69c_row3_col2" class="data row3 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_be69c_row4_col0" class="data row4 col0" >BIG</td>
#       <td id="T_be69c_row4_col1" class="data row4 col1" >1.000</td>
#       <td id="T_be69c_row4_col2" class="data row4 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_be69c_row5_col0" class="data row5 col0" >BOOK</td>
#       <td id="T_be69c_row5_col1" class="data row5 col1" >1.000</td>
#       <td id="T_be69c_row5_col2" class="data row5 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_be69c_row6_col0" class="data row6 col0" >BOY</td>
#       <td id="T_be69c_row6_col1" class="data row6 col1" >1.000</td>
#       <td id="T_be69c_row6_col2" class="data row6 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row7" class="row_heading level0 row7" >11</th>
#       <td id="T_be69c_row7_col0" class="data row7 col0" >BROTHER</td>
#       <td id="T_be69c_row7_col1" class="data row7 col1" >1.000</td>
#       <td id="T_be69c_row7_col2" class="data row7 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row8" class="row_heading level0 row8" >12</th>
#       <td id="T_be69c_row8_col0" class="data row8 col0" >BUT</td>
#       <td id="T_be69c_row8_col1" class="data row8 col1" >1.000</td>
#       <td id="T_be69c_row8_col2" class="data row8 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row9" class="row_heading level0 row9" >13</th>
#       <td id="T_be69c_row9_col0" class="data row9 col0" >C</td>
#       <td id="T_be69c_row9_col1" class="data row9 col1" >1.000</td>
#       <td id="T_be69c_row9_col2" class="data row9 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row10" class="row_heading level0 row10" >14</th>
#       <td id="T_be69c_row10_col0" class="data row10 col0" >CHAIR</td>
#       <td id="T_be69c_row10_col1" class="data row10 col1" >1.000</td>
#       <td id="T_be69c_row10_col2" class="data row10 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row11" class="row_heading level0 row11" >17</th>
#       <td id="T_be69c_row11_col0" class="data row11 col0" >D</td>
#       <td id="T_be69c_row11_col1" class="data row11 col1" >1.000</td>
#       <td id="T_be69c_row11_col2" class="data row11 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row12" class="row_heading level0 row12" >19</th>
#       <td id="T_be69c_row12_col0" class="data row12 col0" >DOCTOR</td>
#       <td id="T_be69c_row12_col1" class="data row12 col1" >1.000</td>
#       <td id="T_be69c_row12_col2" class="data row12 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row13" class="row_heading level0 row13" >24</th>
#       <td id="T_be69c_row13_col0" class="data row13 col0" >FAST</td>
#       <td id="T_be69c_row13_col1" class="data row13 col1" >1.000</td>
#       <td id="T_be69c_row13_col2" class="data row13 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row14" class="row_heading level0 row14" >25</th>
#       <td id="T_be69c_row14_col0" class="data row14 col0" >FRIEND</td>
#       <td id="T_be69c_row14_col1" class="data row14 col1" >1.000</td>
#       <td id="T_be69c_row14_col2" class="data row14 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row15" class="row_heading level0 row15" >28</th>
#       <td id="T_be69c_row15_col0" class="data row15 col0" >GO</td>
#       <td id="T_be69c_row15_col1" class="data row15 col1" >1.000</td>
#       <td id="T_be69c_row15_col2" class="data row15 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row16" class="row_heading level0 row16" >34</th>
#       <td id="T_be69c_row16_col0" class="data row16 col0" >HOLIDAY</td>
#       <td id="T_be69c_row16_col1" class="data row16 col1" >1.000</td>
#       <td id="T_be69c_row16_col2" class="data row16 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row17" class="row_heading level0 row17" >36</th>
#       <td id="T_be69c_row17_col0" class="data row17 col0" >HOT</td>
#       <td id="T_be69c_row17_col1" class="data row17 col1" >1.000</td>
#       <td id="T_be69c_row17_col2" class="data row17 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row18" class="row_heading level0 row18" >39</th>
#       <td id="T_be69c_row18_col0" class="data row18 col0" >IF</td>
#       <td id="T_be69c_row18_col1" class="data row18 col1" >1.000</td>
#       <td id="T_be69c_row18_col2" class="data row18 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_be69c_level0_row19" class="row_heading level0 row19" >42</th>
#       <td id="T_be69c_row19_col0" class="data row19 col0" >K</td>
#       <td id="T_be69c_row19_col1" class="data row19 col1" >1.000</td>
#       <td id="T_be69c_row19_col2" class="data row19 col2" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
import pandas as pd


inv_map = {v: k for k, v in label_map.items()}
num_classes = len(label_map)

def preds_and_labels(manifest_path, bsz=256):
    ds, _ = make_dataset(manifest_path, bsz=bsz, shuffle=False)
    probs, labels = [], []
    for xb, yb in ds:
        pb = best_model(xb, training=False).numpy()
        probs.append(pb)
        labels.append(yb.numpy())
    if not probs:
        return np.zeros((0, num_classes), dtype=np.float32), np.zeros((0,), dtype=np.int64)
    return np.concatenate(probs, 0), np.concatenate(labels, 0)

def per_class_metrics(y_true, y_prob):
    """Return DataFrame with columns: gloss, count, top1, top5."""
    y_pred = y_prob.argmax(1)
    # top-5 membership
    # faster than full sort:
    top5_idx = np.argpartition(-y_prob, kth=4, axis=1)[:, :5]

    rows = []
    for cid in range(num_classes):
        mask = (y_true == cid)
        n = int(mask.sum())
        if n == 0:
            rows.append({"gloss": inv_map[cid], "count": 0, "top1": np.nan, "top5": np.nan})
            continue
        top1 = float((y_pred[mask] == cid).mean())
        top5 = float((top5_idx[mask] == cid).any(axis=1).mean())
        rows.append({"gloss": inv_map[cid], "count": n, "top1": top1, "top5": top5})
    return pd.DataFrame(rows)

# collect per-split frames
split_frames = {}
all_probs = []
all_labels = []

for split_key, man_path in TEST_MANS.items():  # e.g., {"ITW": "...", ...}
    probs, labels = preds_and_labels(man_path, bsz=256)
    all_probs.append(probs)
    all_labels.append(labels)
    df = per_class_metrics(labels, probs)
    df = df.rename(columns={
        "count": f"count_{split_key}",
        "top1":  f"top1_{split_key}",
        "top5":  f"top5_{split_key}",
    })
    split_frames[split_key] = df

# pooled "ALL" across test sets
if all_probs:
    probs_all = np.concatenate(all_probs, 0)
    labels_all = np.concatenate(all_labels, 0)
else:
    probs_all = np.zeros((0, num_classes), dtype=np.float32)
    labels_all = np.zeros((0,), dtype=np.int64)

df_all = per_class_metrics(labels_all, probs_all).rename(columns={
    "count": "count_ALL", "top1": "top1_ALL", "top5": "top5_ALL"
})

from functools import reduce
dfs_to_merge = [df_all] + [split_frames[k] for k in sorted(split_frames.keys())]
df_merged = reduce(lambda l, r: pd.merge(l, r, on="gloss", how="outer"), dfs_to_merge)

col_order = ["gloss",
             "count_ALL", "top1_ALL", "top5_ALL",
             "count_ITW", "top1_ITW", "top5_ITW",
             "count_STU", "top1_STU", "top5_STU",
             "count_SYN", "top1_SYN", "top5_SYN",
             "count_TED", "top1_TED", "top5_TED"]
col_order = [c for c in col_order if c in df_merged.columns]
df_merged = df_merged[col_order].sort_values("gloss").reset_index(drop=True)


pd.set_option("display.max_rows", 1000)
display(df_merged.style.format({c: "{:.3f}" for c in df_merged.columns if c.startswith(("top1","top5"))}))

out_csv = f"{CALLBACK_DIR}/per_class_test_metrics_109.csv"
df_merged.to_csv(out_csv, index=False)
print("Saved per-class test metrics to:", out_csv)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b4bdd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4bdd_level0_col0" class="col_heading level0 col0" >gloss</th>
#       <th id="T_b4bdd_level0_col1" class="col_heading level0 col1" >count_ALL</th>
#       <th id="T_b4bdd_level0_col2" class="col_heading level0 col2" >top1_ALL</th>
#       <th id="T_b4bdd_level0_col3" class="col_heading level0 col3" >top5_ALL</th>
#       <th id="T_b4bdd_level0_col4" class="col_heading level0 col4" >count_ITW</th>
#       <th id="T_b4bdd_level0_col5" class="col_heading level0 col5" >top1_ITW</th>
#       <th id="T_b4bdd_level0_col6" class="col_heading level0 col6" >top5_ITW</th>
#       <th id="T_b4bdd_level0_col7" class="col_heading level0 col7" >count_STU</th>
#       <th id="T_b4bdd_level0_col8" class="col_heading level0 col8" >top1_STU</th>
#       <th id="T_b4bdd_level0_col9" class="col_heading level0 col9" >top5_STU</th>
#       <th id="T_b4bdd_level0_col10" class="col_heading level0 col10" >count_SYN</th>
#       <th id="T_b4bdd_level0_col11" class="col_heading level0 col11" >top1_SYN</th>
#       <th id="T_b4bdd_level0_col12" class="col_heading level0 col12" >top5_SYN</th>
#       <th id="T_b4bdd_level0_col13" class="col_heading level0 col13" >count_TED</th>
#       <th id="T_b4bdd_level0_col14" class="col_heading level0 col14" >top1_TED</th>
#       <th id="T_b4bdd_level0_col15" class="col_heading level0 col15" >top5_TED</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4bdd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4bdd_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_b4bdd_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_b4bdd_row0_col2" class="data row0 col2" >0.625</td>
#       <td id="T_b4bdd_row0_col3" class="data row0 col3" >0.875</td>
#       <td id="T_b4bdd_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_b4bdd_row0_col5" class="data row0 col5" >0.500</td>
#       <td id="T_b4bdd_row0_col6" class="data row0 col6" >1.000</td>
#       <td id="T_b4bdd_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_b4bdd_row0_col8" class="data row0 col8" >1.000</td>
#       <td id="T_b4bdd_row0_col9" class="data row0 col9" >1.000</td>
#       <td id="T_b4bdd_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_b4bdd_row0_col11" class="data row0 col11" >1.000</td>
#       <td id="T_b4bdd_row0_col12" class="data row0 col12" >1.000</td>
#       <td id="T_b4bdd_row0_col13" class="data row0 col13" >2</td>
#       <td id="T_b4bdd_row0_col14" class="data row0 col14" >0.000</td>
#       <td id="T_b4bdd_row0_col15" class="data row0 col15" >0.500</td>
#     </tr>
#     <tr>
#       <th id="T_b4bdd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4bdd_row1_col0" class="data row1 col0" >ARM</td>
#       <td id="T_b4bdd_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_b4bdd_row1_col2" class="data row1 col2" >0.625</td>
#       <td id="T_b4bdd_row1_col3" class="data row1 col3" >1.000</td>
#       <td id="T_b4bdd_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_b4bdd_row1_col5" class="data row1 col5" >1.000</td>
#       <td id="T_b4bdd_row1_col6" class="data row1 col6" >1.000</td>
#       <td id="T_b4bdd_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_b4bdd_row1_col8" class="data row1 col8" >0.500</td>
#       <td id="T_b4bdd_row1_col9" class="data row1 col9" >1.000</td>
#       <td id="T_b4bdd_row1_col10" class="data row1 col10" >2</td>
#       <td id="T_b4bdd_row1_col11" class="data row1 col11" >1.000</td>
#       <td id="T_b4bdd_row1_col12" class="data row1 col12" >1.000</td>
#       <td id="T_b4bdd_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_b4bdd_row1_col14" class="data row1 col14" >0.000</td>
#       <td id="T_b4bdd_row1_col15" class="data row1 col15" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_b4bdd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b4bdd_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_b4bdd_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_b4bdd_row2_col2" class="data row2 col2" >0.625</td>
#       <td id="T_b4bdd_row2_col3" class="data row2 col3" >1.000</td>
#       <td id="T_b4bdd_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_b4bdd_row2_col5" class="data row2 col5" >1.000</td>
#       <td id="T_b4bdd_row2_col6" class="data row2 col6" >1.000</td>
#       <td id="T_b4bdd_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_b4bdd_row2_col8" class="data row2 col8" >1.000</td>
#       <td id="T_b4bdd_row2_col9" class="data row2 col9" >1.000</td>
#       <td id="T_b4bdd_row2_col10" class="data row2 col10" >2</td>
#       <td id="T_b4bdd_row2_col11" class="data row2 col11" >0.000</td>
#       <td id="T_b4bdd_row2_col12" class="data row2 col12" >1.000</td>
#       <td id="T_b4bdd_row2_col13" class="data row2 col13" >2</td>
#       <td id="T_b4bdd_row2_col14" class="data row2 col14" >0.500</td>
#       <td id="T_b4bdd_row2_col15" class="data row2 col15" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_b4bdd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b4bdd_row3_col0" class="data row3 col0" >BABY</td>
#       <td id="T_b4bdd_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_b4bdd_row3_col2" class="data row3 col2" >0.750</td>
#       <td id="T_b4bdd_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_b4bdd_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_b4bdd_row3_col5" class="data row3 col5" >1.000</td>
#       <td id="T_b4bdd_row3_col6" class="data row3 col6" >1.000</td>
#       <td id="T_b4bdd_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_b4bdd_row3_col8" class="data row3 col8" >0.500</td>
#       <td id="T_b4bdd_row3_col9" class="data row3 col9" >1.000</td>
#       <td id="T_b4bdd_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_b4bdd_row3_col11" class="data row3 col11" >1.000</td>
#       <td id="T_b4bdd_row3_col12" class="data row3 col12" >1.000</td>
#       <td id="T_b4bdd_row3_col13" class="data row3 col13" >2</td>
#       <td id="T_b4bdd_row3_col14" class="data row3 col14" >0.500</td>
#       <td id="T_b4bdd_row3_col15" class="data row3 col15" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_b4bdd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b4bdd_row4_col0" class="data row4 col0" >BAD</td>
#       <td id="T_b4bdd_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_b4bdd_row4_col2" class="data row4 col2" >0.250</td>
#       <td id="T_b4bdd_row4_col3" class="data row4 col3" >0.500</td>
#       <td id="T_b4bdd_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_b4bdd_row4_col5" class="data row4 col5" >0.000</td>
#       <td id="T_b4bdd_row4_col6" class="data row4 col6" >0.000</td>
#       <td id="T_b4bdd_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_b4bdd_row4_col8" class="data row4 col8" >0.500</td>
#       <td id="T_b4bdd_row4_col9" class="data row4 col9" >0.500</td>
#       <td id="T_b4bdd_row4_col10" class="data row4 col10" >2</td>
#       <td id="T_b4bdd_row4_col11" class="data row4 col11" >0.000</td>
#       <td id="T_b4bdd_row4_col12" class="data row4 col12" >1.000</td>
#       <td id="T_b4bdd_row4_col13" class="data row4 col13" >2</td>
#       <td id="T_b4bdd_row4_col14" class="data row4 col14" >0.500</td>
#       <td id="T_b4bdd_row4_col15" class="data row4 col15" >0.500</td>
#     </tr>
#     <tr>
#       <th id="T_b4bdd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b4bdd_row5_col0" class="data row5 col0" >BED</td>
#       <td id="T_b4bdd_row5_col1" class="data row5 col1" >8</td>
#       <td id="T_b4bdd_row5_col2" class="data row5 col2" >0.625</td>
#       <td id="T_b4bdd_row5_col3" class="data row5 col3" >1.000</td>
#       <td id="T_b4bdd_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_b4bdd_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_b4bdd_row5_col6" class="data row5 col6" >1.000</td>
#       <td id="T_b4bdd_row5_col7" class="data row5 col7" >2</td>
#       <td id="T_b4bdd_row5_col8" clas
# Saved per-class test metrics to: /content/drive/MyDrive/109-keypoints-all-64/model-callbacks-keras/per_class_test_metrics_109.csv

# %%
import os, csv
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

log_path = Path(CALLBACK_DIR) / "train_log.csv"

histories = []
if "history" in globals() and hasattr(history, "history"):
    histories.append(history.history)
if "history2" in globals() and hasattr(history2, "history"):
    histories.append(history2.history)

def concat_histories(hlist, key):
    vals = []
    for h in hlist:
        if key in h:
            vals.extend(h[key])
    return np.array(vals, dtype=float) if vals else None

h_loss  = concat_histories(histories, "loss")
h_vloss = concat_histories(histories, "val_loss")
h_acc   = concat_histories(histories, "accuracy")
h_vacc  = concat_histories(histories, "val_accuracy")

csv_loss = csv_vloss = csv_acc = csv_vacc = None
if log_path.exists():
    loss_list, vloss_list, acc_list, vacc_list = [], [], [], []
    with open(log_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        for row in reader:
            # Defensive parse (handles missing columns)
            if "loss" in row and row["loss"] != "":
                loss_list.append(float(row["loss"]))
            if "val_loss" in row and row["val_loss"] != "":
                vloss_list.append(float(row["val_loss"]))
            if "accuracy" in row and row["accuracy"] != "":
                acc_list.append(float(row["accuracy"]))
            if "val_accuracy" in row and row["val_accuracy"] != "":
                vacc_list.append(float(row["val_accuracy"]))
    if loss_list:  csv_loss  = np.array(loss_list,  dtype=float)
    if vloss_list: csv_vloss = np.array(vloss_list, dtype=float)
    if acc_list:   csv_acc   = np.array(acc_list,   dtype=float)
    if vacc_list:  csv_vacc  = np.array(vacc_list,  dtype=float)


plt.figure(figsize=(7,5))
if h_loss is not None:  plt.plot(h_loss,  label="train loss (this run)")
if h_vloss is not None: plt.plot(h_vloss, label="val loss (this run)")
if csv_loss is not None:  plt.plot(csv_loss,  linestyle="--", label="train loss (CSV)")
if csv_vloss is not None: plt.plot(csv_vloss, linestyle="--", label="val loss (CSV)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(7,5))
if h_acc is not None:  plt.plot(h_acc,  label="train acc (this run)")
if h_vacc is not None: plt.plot(h_vacc, label="val acc (this run)")
if csv_acc is not None:  plt.plot(csv_acc,  linestyle="--", label="train acc (CSV)")
if csv_vacc is not None: plt.plot(csv_vacc, linestyle="--", label="val acc (CSV)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()
